# %% [markdown]
# ## Answers for week 1
#
# * Name: Tomasz Kaminski
# * Username: tpkaminski
# * Student s-number: S5756111
# * Group: AS6

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 #processed on jupyter hub

# %% [markdown]
# # Q1.5

# %%
m = 7.342e22
e = 5.9722e24
G = 6.6743e-11
r = 385000600
F = (G*m*e)/(r*r)
print(F)
# Out:
# 1.974384051807571e+20

# %%
#Q 16: Kepler's third law
from scipy.constants import G, pi
a = 150e9
P = 31556926
# M = m1 + m2
M = ((4*pi**2)/G)*(a**3/P**2)
print(M)
# Out:
# 2.0046493032030391e+30

# %% [markdown]
# ![Screenshot.png](attachment:Screenshot.png)

# %% [markdown]
# ## Q15 and 16
#
# result of pwd command: /Users/users/tpkaminski/Downloads
#
# "." is "Downloads" and ".." is home directory
#
# "cd ~/Desktop"

# %% [markdown]
# ### Q11 and 12
# ![Screenshot_q11.png](attachment:Screenshot_q11.png)

# %% [markdown]
# ![Screenshotq12.png](attachment:Screenshotq12.png)
